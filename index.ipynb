# %% [markdown]
# ## Exploratory Data Analysis
# Typically, whenever we are handed a new dataset or problem our first step is to begin to wrap our head around the problem and the data associated with it. This is where some of our previous tools such as the measure of center and dispersion will come in handy. From there, we can continue to dissect the problem by employing various techniques and algorithms to further analyze the dataset from various angles.
#
# ### Here we'll investigate a classic dataset concerning the Titanic.

# %% [markdown]
# #### First let's import the dataset, see how long it is and preview the first 5 rows

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
print(len(df))
df.head()
# Out:
# 891
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Then let's quickly get some more info about each of our column features:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# #### We can also quickly visualize the data:
# Along the diagonal are the distributions for each of our variables. Every other cell shows a correlation plot of one feature against another feature.

# %%
import matplotlib.pyplot as plt

# %%
pd.plotting.scatter_matrix(df, figsize=(10,10));

# %% [markdown]
# # Create a graph displaying the distribution of those who survived
# (Any appropriate graph works including pie chart or bar chart or other appropriate.)

# %%
df.Survived.plot.hist()

# %% [markdown]
# # Create a graph depicting the survival distribution by gender.

# %%
df.groupby('Sex')['Survived'].plot.hist()
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Survived, dtype: object

# %% [markdown]
# # Create a graph depicting survival by age

# %%
df.groupby('Age')['Survived'].plot.scatter()
# Out:
# AttributeErrorTraceback (most recent call last)
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self)
#     547             def f(self):
# --> 548                 return getattr(self.plot, name)(*args, **kwargs)
#     549             return self._groupby.apply(f)
#
# AttributeError: 'SeriesPlotMethods' object has no attribute 'scatter'
#
# During handling of the above exception, another exception occurred:
#
# AttributeErrorTraceback (most recent call last)
# <ipython-input-30-2033cb9ac46c> in <module>()
# ----> 1 df.groupby('Age')['Survived'].plot.scatter()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in attr(*args, **kwargs)
#     547             def f(self):
#     548                 return getattr(self.plot, name)(*args, **kwargs)
# --> 549             return self._groupby.apply(f)
#     550         return attr
#     551
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    3467                       examples=_apply_docs['series_examples']))
#    3468     def apply(self, func, *args, **kwargs):
# -> 3469         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#    3470
#    3471     @Appender(_agg_doc)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self)
#     546         def attr(*args, **kwargs):
#     547             def f(self):
# --> 548                 return getattr(self.plot, name)(*args, **kwargs)
#     549             return self._groupby.apply(f)
#     550         return attr
#
# AttributeError: 'SeriesPlotMethods' object has no attribute 'scatter'

# %% [markdown]
# # Create a new colmn age bracket with the following categories:
# * 0-12 years old
# * 12-18 years old
# * 18-25 years old
# * 25-35 years old
# * 35-45 years old
# * 45-65 years old
# * 65+ years old

# %%
ageBracket_dict = {'0-12': [],
                  '12-18': [],
                  '18-25': [],
                  '25-35': [],
                  '35-45': [],
                  '45-65': [],
                  '65+': []}
for item in df.Age:
    if item in range(0,12):
        ageBracket_dict('0-12').append(item)
    elif item in range(12,18):
        ageBracket_dict('12-18').append(item)
    elif item in range(18,25):
        ageBracket_dict('18-25').append(item)
    elif item in range(25,35):
        ageBracket_dict('25-35').append(item)
    elif item in range(35,45):
        ageBracket_dict('35-45').append(item)
    elif item in range(45,65):
        ageBracket_dict('45-65').append(item)
    else:
        ageBracket_dict('65+').append(item)
        
df['Age Bracket'] = df.Age.map(ageBracket_dict)
df.head()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-22-3b109db1007b> in <module>()
#      12         ageBracket_dict('12-18').append(item)
#      13     elif item in range(18,25):
# ---> 14         ageBracket_dict('18-25').append(item)
#      15     elif item in range(25,35):
#      16         ageBracket_dict('25-35').append(item)
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# # Create a graph displaying the distribution of those who survived by the age brackets created above

# %%
#Your code here

# %% [markdown]
# # Explore at least 3 other relationships within the data.

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here
